# %% [markdown]
# <a href="https://colab.research.google.com/github/YagyanshB/100-days-of-python/blob/main/sets.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
set1 = {1,3,4}

# %%
# duplicate values in sets

# %%
set2 = {1,3,4,1,4}

# %%
print(set2)
# Out:
# {1, 3, 4}

# %%
set2a = {1,3,4,True}

# %%
set2a
# Out:
# {1, 3, 4}

# %%
set3 = {1, 'Yagyansh', 4, True}

# %%
set3
# Out:
# {1, 4, 'Yagyansh'}

# %%
len(set3)
# Out:
# 3

# %%
# add to set

# %%
set3.add("Cricket")

# %%
set3
# Out:
# {1, 4, 'Cricket', 'Yagyansh'}

# %%
# remove from set

# %%
set3.remove("Cricket")

# %%
set3
# Out:
# {1, 4, 'Yagyansh'}

# %%
set3.discard("Yagyansh")

# %%
set3
# Out:
# {1, 4}

# %%
# clearing your whole set

# %%
set3.clear()

# %%
set3
# Out:
# set()

# %%
emptyset = set()

# %%
emptyset
# Out:
# set()

# %%
type(emptyset)
# Out:
# set

# %%
set2 = {1,3,4,1,4}
set3 = {1, 'Yagyansh', 4, True}

# %%
union1 = set3.union(set2)

# %%
union1
# Out:
# {1, 3, 4, 'Yagyansh'}

# %%
# the above creates one set with all unique elements

# %%
union2 = set3 | set2

# %%
union2
# Out:
# {1, 3, 4, 'Yagyansh'}

# %%
intersection1 = set3.intersection(set2)

# %%
intersection1
# Out:
# {1, 4}

# %%
intersection2 = set3 & set2

# %%
intersection2
# Out:
# {1, 4}

# %%
difference1 = set3.difference(set2)

# %%
difference1
# Out:
# {'Yagyansh'}

# %%
difference2 = set3 - set2

# %%
difference2
# Out:
# {'Yagyansh'}

# %%
difference3 = set2 - set3

# %%
difference3
# Out:
# {3}

# %%
mul1 = {1,11,7}
mul2 = {6,11,7}
mul3 = {13,11,9}

# %%
multest = mul1 & mul2 & mul3

# %%
multest
# Out:
# {11}

# %%
11 in multest
# Out:
# True

# %%
23 not in multest
# Out:
# True

# %%
multest
# Out:
# {11}

# %%
set1 = {11,12,5,1}
set2 = {6,8,4}
set3 = {6,8,4,11,11}

# %%
set1.isdisjoint(set2)
# Out:
# True

# %%
set2.issubset(set3)
# Out:
# True

# %%
set3.issuperset(set2)
# Out:
# True

# %%
# loops

for number in set1:
  print(number)
# Out:
# 1
# 11
# 12
# 5

# %%
hof_cricketers = {
    "Sachin",
    "Virat",
    "MS",
    "Sourav",
    "Jasprit"
}

# %%
hof_cricketers
# Out:
# {'Jasprit', 'MS', 'Sachin', 'Sourav', 'Virat'}

# %%
for cricketer in hof_cricketers:
  print(cricketer)
# Out:
# MS
# Sourav
# Virat
# Jasprit
# Sachin

# %%
pitcher_list = list(hof_cricketers)

# %%
pitcher_list[0]
# Out:
# 'MS'

# %%
for index, cricketer in enumerate(hof_cricketers):
  print(index, cricketer)
# Out:
# 0 MS
# 1 Sourav
# 2 Virat
# 3 Jasprit
# 4 Sachin
