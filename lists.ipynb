# %% [markdown]
# <a href="https://colab.research.google.com/github/YagyanshB/100-days-of-python/blob/main/lists.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
list_nums = [1292, 8921]

# %%
list_nums[0]
# Out:
# 1292

# %%
list_letters = ['Y', 'B', 'y', 'b']

# %%
list_letters[0]
# Out:
# 'Y'

# %%
list_num_letters = ['y', '2', 'b', '8']

# %%
list_num_letters
# Out:
# ['y', '2', 'b', '8']

# %%
list_with_a_list = [[1,4], ['y', 'b']]

# %%
list_with_a_list
# Out:
# [[1, 4], ['y', 'b']]

# %%
# Grab Elements

# %%
print(list_nums)
# Out:
# [1292, 8921]

# %%
for num in list_nums:
    print(num)
# Out:
# 1292
# 8921

# %%
list_nums[1]
# Out:
# 8921

# %%
list_letters[-1]
# Out:
# 'b'

# %%
list_letters[-2]
# Out:
# 'y'

# %%
# Multiple Element Grabbing

list_letters[0:4]
# Out:
# ['Y', 'B', 'y', 'b']

# %%
list_letters
# Out:
# ['Y', 'B', 'y', 'b']

# %%
# Print out every second letter

for letter in list_letters[0::2]:
    print(letter)
# Out:
# Y
# y

# %%
# Unpacking

one, two, three, four = list_letters

# %%
print(one)
# Out:
# Y

# %%
one, two, *other = list_letters

# %%
print(one)
# Out:
# Y

# %%
print(*other)
# Out:
# y b

# %%
# elements being replaced

list_nums
# Out:
# [1292, 8921]

# %%
list_nums[0] = 1000

# %%
# sorting lists

list_letters
# Out:
# ['Y', 'B', 'y', 'b']

# %%
list_letters.sort()

# %%
list_letters
# Out:
# ['B', 'Y', 'b', 'y']

# %%
sorted(list_letters)
# Out:
# ['B', 'Y', 'b', 'y']

# %%
# Rerverse our order

list_letters.reverse()

# %%
list_letters
# Out:
# ['y', 'b', 'Y', 'B']

# %%
reversed(list_letters)

# %%
list_nums
# Out:
# [1000, 8921]

# %%
list_nums.sort(reverse = True)

# %%
list_nums
# Out:
# [8921, 1000]

# %%
# return indexes

list_nums
# Out:
# [8921, 1000]

# %%
list_nums.index(8921)
# Out:
# 0

# %%
# add to lists

list_nums.extend([28, 9])

# %%
list_nums
# Out:
# [8921, 1000, 28, 9]

# %%
list_nums.append(100)

# %%
list_nums
# Out:
# [8921, 1000, 28, 9, 100]

# %%
list_nums.insert(0, 2409)

# %%
list_nums
# Out:
# [2409, 8921, 1000, 28, 9, 100]

# %%
# removing from a list

list_nums.remove(100)

# %%
list_nums.pop(1)
# Out:
# 8921

# %%
list_nums
# Out:
# [2409, 1000, 28, 9]

# %%
list_nums.clear()

# %%
list_nums
# Out:
# []

# %%
# loops with lists

for letter in list_letters:
  print(letter)
# Out:
# y
# b
# Y
# B

# %%
for index, letter in enumerate(list_letters):
  print(index, letter)
# Out:
# 0 y
# 1 b
# 2 Y
# 3 B

# %%
for index, letter in enumerate(list_letters, start = -1):
  print(index, letter)
# Out:
# -1 y
# 0 b
# 1 Y
# 2 B

# %%
# memory on list

list_letters2 = list_letters

# %%
list_letters2
# Out:
# ['y', 'b', 'Y', 'B']

# %%
list_letters3 = list_letters[:]

# %%
list_letters3
# Out:
# ['y', 'b', 'Y', 'B']

# %%
list_letters4 = list_letters.copy()

# %%
list_letters4
# Out:
# ['y', 'b', 'Y', 'B']

# %%
# misc

list_str = ' | '.join(list_letters)

# %%
list_str
# Out:
# 'y | b | Y | B'

# %%
list_letters_from_str = list_str.split(' | ')

# %%
list_letters_from_str
# Out:
# ['y', 'b', 'Y', 'B']

# %%
type(list_str)
# Out:
# str
