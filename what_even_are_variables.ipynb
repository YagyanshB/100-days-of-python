# %% [markdown]
# <a href="https://colab.research.google.com/github/YagyanshB/100-days-of-python/blob/main/what_even_are_variables.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Example 1 varible that's an integer

# %%
strikeouts = 514

# %%
print(strikeouts)
# Out:
# 514

# %%
print(type(strikeouts))
# Out:
# <class 'int'>

# %%
# Example 2 variable that's a float

# %%
salary = 800.78

# %%
print(type(salary))
# Out:
# <class 'float'>

# %%
# Example 3 variable that's a string

# %%
position = 'Pitcher'

# %%
print(type(position))
# Out:
# <class 'str'>

# %%
print(position)
# Out:
# Pitcher

# %%
# Example 4 variable that's a Boolean

# %%
hall_of_fame = True

# %%
type(hall_of_fame)
# Out:
# bool

# %%
print(hall_of_fame)
# Out:
# True

# %%
# Example 5 is chained assignments

# %%
Wins, Losses, WHIP = 324, 292, 1.247

# %%
Wins
# Out:
# 324

# %%
Losses
# Out:
# 292

# %%
WHIP
# Out:
# 1.247

# %%
type(Wins)
# Out:
# int

# %%
type(Losses)
# Out:
# int

# %%
type(WHIP)
# Out:
# float

# %%
# Example 6 is changing values

# %%
Losses = 100

# %%
Losses
# Out:
# 100

# %%
Losses = 292

# %%
# Example 7 is combining variables

# %%
first_name = 'Yagyansh'

# %%
last_name = 'Bagri'

# %%
full_name = first_name + ' ' + last_name

# %%
print(full_name)
# Out:
# Yagyansh Bagri

# %%
# Example 8 longer strings with casting

# %%
full_name_number = first_name + ' ' + last_name + ' Number: ' + str(28)

# %%
full_name_number
# Out:
# 'Yagyansh Bagri Number: 28'
