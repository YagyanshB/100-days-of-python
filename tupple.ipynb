# %% [markdown]
# <a href="https://colab.research.google.com/github/YagyanshB/100-days-of-python/blob/main/tupple.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
tuple1 = (1, 4, 5, 6)

# %%
tuple1
# Out:
# (1, 4, 5, 6)

# %%
# tuples are ordered

# %%
tuple1[0]
# Out:
# 1

# %%
tuple1[1]
# Out:
# 4

# %%
tuple1[0:2]
# Out:
# (1, 4)

# %%
len(tuple1)
# Out:
# 4

# %%
max(tuple1)
# Out:
# 6

# %%
min(tuple1)
# Out:
# 1

# %%
tuple2 = ('Yagyansh', )

# %%
tuple2
# Out:
# ('Yagyansh',)

# %%
tuple3 = ()

# %%
tuple4 = ('Nolan', 1, True)

# %%
tuple4
# Out:
# ('Nolan', 1, True)

# %%
tuple5 = tuple4 + tuple1

# %%
tuple5
# Out:
# ('Nolan', 1, True, 1, 4, 5, 6)

# %%
del tuple5

# %%
tuple6 = (tuple1, tuple4, )

# %%
tuple6
# Out:
# ((1, 4, 5, 6), ('Nolan', 1, True))

# %%
tuple6[0]
# Out:
# (1, 4, 5, 6)

# %%
list_1 = [1, 4, 5, 7, 90, 8]

# %%
list_1_tuple = tuple(list_1)

# %%
list_1_tuple
# Out:
# (1, 4, 5, 7, 90, 8)

# %%
dict = {'a': 2, 'b': 5, 'c': 8}

# %%
dict_tuple = tuple(dict.values())

# %%
dict_tuple
# Out:
# (2, 5, 8)

# %%
tuple7 = tuple2 * 6

# %%
tuple7
# Out:
# ('Yagyansh', 'Yagyansh', 'Yagyansh', 'Yagyansh', 'Yagyansh', 'Yagyansh')

# %%
6 in tuple1
# Out:
# True

# %%
8 not in tuple1
# Out:
# True

# %%
cricket_players = ('Kohli', 'Rohit', 'Jasprit', 'Shane', 'Pat')

# %%
for player in cricket_players:
    print(player)
# Out:
# Kohli
# Rohit
# Jasprit
# Shane
# Pat

# %%
# packing and unpacking with tuples

cricketer_1, cricketer_2, cricketer_3, cricketer_4, cricketer_5 = cricket_players

# %%
tuple8 = (4, 6, 3, 8, 2)

# %%
sorted(tuple8)
# Out:
# [2, 3, 4, 6, 8]

# %%
sorted(tuple8, reverse = True)
# Out:
# [8, 6, 4, 3, 2]

# %%
tuple9 = (1, 2, 3, 1, 1)

# %%
tuple9.count(1)
# Out:
# 3

# %%
tuple9.index(2)
# Out:
# 1

# %%
def square_calcs(length):

  area = length * length
  perimeter = 4 * length
  return area, perimeter

# %%
square_calcs(5)
# Out:
# (25, 20)
