# %% [markdown]
# <a href="https://colab.research.google.com/github/YagyanshB/100-days-of-python/blob/main/loops_hoops.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Example 1 with a basic if else statement

# %%
batting_average = 0.33

# %%
if batting_average > 0.3:
  print("Good Batter")

elif batting_average >= 0.25:
  print("Decent Batter")

else:
  print("Needs to Improve")
# Out:
# Good Batter

# %%
batting_average = float(input("Please enter your batting Average: "))

if batting_average > 0.3:
  print("Good Batter")

elif batting_average >= 0.25:
  print("Decent Batter")

else:
  print("Needs to Improve")
# Out:
# Please enter your batting Average: 23
# Good Batter

# %%
batting_average
# Out:
# 23.0

# %%
# Example 2 with Multiple Conditions

# %%
hits = int(input("Please enter your total number of hits: "))
home_runs = int(input("Please enter your total number of home runs: "))

if hits > 150 and home_runs > 30:
  print("Great all round player")

elif hits > 150:
  print("Great contact hitter")

elif home_runs > 25:
  print("Great power hitter")

else:
  print("Average Player")
# Out:
# Please enter your total number of hits: 100
# Please enter your total number of home runs: 42
# Great power hitter

# %%
# Example 3 with True conditions

# %%
fast_runner = True

outs = 2
balls = 3
strikes = 2

# %%
if fast_runner or (outs == 2 and balls == 3 and strikes == 2):
  print("Can Steal Base")

else:
  print("Can't Steal Base")
# Out:
# Can Steal Base

# %%
# Example NOT!=

if not fast_runner or (outs !=2 and balls != 3 and strikes != 2):
  print("Can Steal Base")

else:
  print("Can't Steal Base")
# Out:
# Can't Steal Base

# %%
# Example 5 Nested conditions

runs_scored = 7
innings_played = 9

if innings_played == 9:
  if runs_scored >= 6:
    print("High Scoring Game")
  else:
    print("Moderate Scoring Game")
else:
  print("Game is not complete")
# Out:
# High Scoring Game

# %%
item_list = ['Yankees', 'Red Sox', 'Dodgers', 'Cubs', 'Rays']

# %%
team_a = item_list[0]

# %%
team_a
# Out:
# 'Yankees'

# %%
player_stats = {
    "player1": {"name": "Yagyansh", "hits": 343, "home_runs": 30},
    "player2": {"name": "Ansh", "hits": 298, "home_runs": 25},
    "player3": {"name": "Aakash", "hits": 401, "home_runs": 42}
}

# %%
for player, stats in player_stats.items():
  if stats["hits"] is None:
    print()

# %%
for stats in player_stats.values():
  print(stats)
# Out:
# {'name': 'Yagyansh', 'hits': 343, 'home_runs': 30}
# {'name': 'Ansh', 'hits': 298, 'home_runs': 25}
# {'name': 'Aakash', 'hits': 401, 'home_runs': 42}

# %%
# Ternary Expression

retired_years = 6
hof = "eliguble" if retired_years >= 6 else "not eligible"

# %%
hof
# Out:
# 'eliguble'
