# %% [markdown]
# <a href="https://colab.research.google.com/github/YagyanshB/100-days-of-python/blob/main/dictionaries.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# linked

{"Key": 'Value', "Key2": 'Value2'}
# Out:
# {'Key': 'Value', 'Key2': 'Value2'}

# %%
coder = {'name': 'Yagyansh', 'age': 26, 'languages': ['SQL', 'Python']}

# %%
coder
# Out:
# {'name': 'Yagyansh', 'age': 26, 'languages': ['SQL', 'Python']}

# %%
coder['name']
# Out:
# 'Yagyansh'

# %%
coder['languages'][0]
# Out:
# 'SQL'

# %%
coder['languages'][1]
# Out:
# 'Python'

# %%
coder.keys()
# Out:
# dict_keys(['name', 'age', 'languages'])

# %%
coder.items()
# Out:
# dict_items([('name', 'Yagyansh'), ('age', 26), ('languages', ['SQL', 'Python'])])

# %%
for item in coder:
  print(item)
# Out:
# name
# age
# languages

# %%
for item in coder.items():
  print(item)
# Out:
# ('name', 'Yagyansh')
# ('age', 26)
# ('languages', ['SQL', 'Python'])

# %%
coder.values()
# Out:
# dict_values(['Yagyansh', 26, ['SQL', 'Python']])

# %%
for data in coder.values():
  print(data)
# Out:
# Yagyansh
# 26
# ['SQL', 'Python']

# %%
coder.keys()
# Out:
# dict_keys(['name', 'age', 'languages'])

# %%
for key in coder.keys():
  print(key)
# Out:
# name
# age
# languages

# %%
for key, value in coder.items():
  print(key, ":", value)
# Out:
# name : Yagyansh
# age : 26
# languages : ['SQL', 'Python']

# %%
# getting items from dictionaries

# %%
coder.get('name')
# Out:
# 'Yagyansh'

# %%
print(coder.get('company'))
# Out:
# None

# %%
print(coder.get('company', 'not found'))
# Out:
# not found

# %%
# create an item

# %%
coder["company"] = "Netflix"

# %%
coder.get('company')
# Out:
# 'Netflix'

# %%
coder.items()
# Out:
# dict_items([('name', 'Yagyansh'), ('age', 26), ('languages', ['SQL', 'Python']), ('company', 'Netflix')])

# %%
coder.values()
# Out:
# dict_values(['Yagyansh', 26, ['SQL', 'Python'], 'Netflix'])

# %%
# update

# %%
coder.update({'name': 'Yagyansh Bagri'})

# %%
coder
# Out:
# {'name': 'Yagyansh Bagri',
#  'age': 26,
#  'languages': ['SQL', 'Python'],
#  'company': 'Netflix'}

# %%
# delete

# %%
del coder['company']

# %%
coder
# Out:
# {'name': 'Yagyansh Bagri', 'age': 26, 'languages': ['SQL', 'Python']}

# %%
# pop

# %%
languages = coder.pop('languages')

# %%
languages
# Out:
# ['SQL', 'Python']

# %%
coder
# Out:
# {'name': 'Yagyansh Bagri', 'age': 26}

# %%
age = coder.pop('age')

# %%
coder
# Out:
# {'name': 'Yagyansh Bagri'}

# %%
# pop item

# %%
coder.popitem()
# Out:
# ('name', 'Yagyansh Bagri')

# %%
coder
# Out:
# {}

# %%
coder = {'name': 'Yagyansh', 'age': 26, 'languages': ['SQL', 'Python']}

# %%
coder
# Out:
# {'name': 'Yagyansh', 'age': 26, 'languages': ['SQL', 'Python']}

# %%
coder.popitem()
# Out:
# ('languages', ['SQL', 'Python'])

# %%
coder
# Out:
# {'name': 'Yagyansh', 'age': 26}

# %%
coder = {'name': 'Yagyansh', 'age': 26, 'languages': ['SQL', 'Python']}

# %%
# length of dictionary

# %%
len(coder)
# Out:
# 3

# %%
# returns 3 because of the relationships in the dictionary

# %%
# another way to create a dictionary

# %%
cricket = dict(team = 'India', captain = 'Virat Kohli')

# %%
cricket
# Out:
# {'team': 'India', 'captain': 'Virat Kohli'}

# %%
#memory

# %%
cc2 = cricket

# %%
cc2['division'] = 'Champions League'

# %%
cricket
# Out:
# {'team': 'India', 'captain': 'Virat Kohli', 'division': 'Champions League'}

# %%
cc3 = cricket.copy()

# %%
cc3['decade'] = 2000

# %%
cricket
# Out:
# {'team': 'India', 'captain': 'Virat Kohli', 'division': 'Champions League'}

# %%
cc3
# Out:
# {'team': 'India',
#  'captain': 'Virat Kohli',
#  'division': 'Champions League',
#  'decade': 2000}

# %%
# clear

# %%
cc3.clear()

# %%
cc3
# Out:
# {}

# %%
cc2.clear()

# %%
cc2
# Out:
# {}

# %%
cc2 = cricket.copy()

# %%
cc2
# Out:
# {}

# %%
# set default

# %%
cricket.setdefault('team', 'India')
# Out:
# 'India'

# %%
cricket
# Out:
# {'team': 'India'}

# %%
# create dictionary from keys

# %%
teams = ['RCB', 'KKR', 'CSK']
wins = 0

# %%
west = dict.fromkeys(teams, wins)

# %%
west
# Out:
# {'RCB': 0, 'KKR': 0, 'CSK': 0}
